# %%
import torch

# %%
! nvidia-smi
# Out:
# Fri Apr 17 16:50:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 596.21                 Driver Version: 596.21         CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   47C    P5             23W /  200W |    2229MiB /  12282MiB |     38%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            5368    C+G   ...Next\CNext\RadeonSoftware.exe      N/A      |
# |    0   N/A  N/A            5988    C+G   ....0.3967.12\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            7668    C+G   ....0.3967.12\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            9252    C+G   ....0.3967.12\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           10820    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           11244    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           12784    C+G   ...lus\logioptionsplus_agent.exe      N/A      |
# |    0   N/A  N/A           13172    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           13456    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           13508    C+G   ...25.1.1\jbr\bin\cef_server.exe      N/A      |
# |    0   N/A  N/A           14460    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           14888    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           14932    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           15168    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           15824    C+G   ...\cef.win64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A           15944    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           17756    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           18452    C+G   ....0.3967.12\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           19600    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           22040    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           22320    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           23992    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           25264    C+G   ...D\CNext\CNext\AMDRSSrcExt.exe      N/A      |
# |    0   N/A  N/A           28312    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           34640    C+G   ...a\Roaming\Spotify\Spotify.exe      N/A      |
# |    0   N/A  N/A           39120    C+G   ...p\app-3.5.7\GitHubDesktop.exe      N/A      |
# |    0   N/A  N/A           39924    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           41196    C+G   ...ogram Files\Zotero\zotero.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
print(torch.cuda.is_available())
print(f'* CUDA Device: {torch.cuda.get_device_name("cuda:0")}\n* Device Properties: {torch.cuda.get_device_properties("cuda:0")}')

# device = torch.cuda.device(0)
device = torch.device('cuda:0')
# Out:
# True
# * CUDA Device: NVIDIA GeForce RTX 4070
# * Device Properties: _CudaDeviceProperties(name='NVIDIA GeForce RTX 4070', major=8, minor=9, total_memory=12281MB, multi_processor_count=46, uuid=f2da3a1e-bdf3-094c-8f5b-f221eb8ef48a, pci_bus_id=1, pci_device_id=0, pci_domain_id=0, L2_cache_size=36MB)
