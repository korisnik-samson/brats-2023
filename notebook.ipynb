# %%
import torch

# %%
! nvidia-smi
# Out:
# Wed Apr 22 11:05:30 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 596.21                 Driver Version: 596.21         CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   44C    P8             17W /  200W |    2170MiB /  12282MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2984    C+G   ...25.1.1\jbr\bin\cef_server.exe      N/A      |
# |    0   N/A  N/A            3532    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A            4520    C+G   ...Next\CNext\RadeonSoftware.exe      N/A      |
# |    0   N/A  N/A            8712    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A            9956    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           11444    C+G   ...\cef.win64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A           12548    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           13052    C+G   ...lus\logioptionsplus_agent.exe      N/A      |
# |    0   N/A  N/A           15716    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           15740    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           16976    C+G   ...eted\001A0000000C715E57559E96      N/A      |
# |    0   N/A  N/A           18260    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           19196    C+G   ....0.3967.20\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           21392    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           22332    C+G   ...D\CNext\CNext\AMDRSSrcExt.exe      N/A      |
# |    0   N/A  N/A           22392    C+G   ...eted\001A0000000C715E57559E96      N/A      |
# |    0   N/A  N/A           23456    C+G   ...eted\001A0000000C715E57559E96      N/A      |
# |    0   N/A  N/A           23872    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           23896    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           25572    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           30792    C+G   ...a\Roaming\Spotify\Spotify.exe      N/A      |
# |    0   N/A  N/A           33664    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           34292    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           34520    C+G   ...4__8wekyb3d8bbwe\ms-teams.exe      N/A      |
# |    0   N/A  N/A           46608    C+G   ....0.3967.20\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           51296    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           53096    C+G   ...4__8wekyb3d8bbwe\ms-teams.exe      N/A      |
# |    0   N/A  N/A           56088    C+G   ...indows\System32\ShellHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
print(torch.cuda.is_available())
print(f'* CUDA Device: {torch.cuda.get_device_name("cuda:0")}\n* Device Properties: {torch.cuda.get_device_properties("cuda:0")}')

# device = torch.cuda.device(0)
device = torch.device('cuda:0')
# Out:
# True
# * CUDA Device: NVIDIA GeForce RTX 4070
# * Device Properties: _CudaDeviceProperties(name='NVIDIA GeForce RTX 4070', major=8, minor=9, total_memory=12281MB, multi_processor_count=46, uuid=f2da3a1e-bdf3-094c-8f5b-f221eb8ef48a, pci_bus_id=1, pci_device_id=0, pci_domain_id=0, L2_cache_size=36MB)
